# %% [markdown]
# # Binome :
# MESSAOUDI Melissa
#
# abelbaki guir

# %% [markdown]
# ## Transfer Learning using Convlutional Neural Networks:
#
# **Motivation**:
#
# Training a deep neural network model from scratch can be difficult with limited data and computational resources. It takes a lot of effort to manually annotate a training dataset, an interesting solution would be to reuse already pre-trained models, for example: ResNet or VGG models trained on a large-scale datasets.
#
# That is to say, we can leverage the information learned by one of those models to perform a specific task.
#
#
#
#
# ![TL.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # I. Training from scratch

# %% [markdown]
# **Objectives**
# - You will use a pre-trained convolutional neural network on ImageNet dataset to perform classification on another small dataset.
#
# # 1. Packages:
# 1.  [numpy](www.numpy.org) library used for numerical computing with Python.
# 2.  [matplotlib](www.matplotlib.org) to create graphs and show images in python.
# 3.  [Tensorflow](www.tensorflow.org) machine learning platform. This framework makes it easy to express high-level abstractions to build end-to-end deep neural networks (From data preparation to Model deployment)
# 4. [sklearn](https://scikit-learn.org) open source data analysis library, include machine learning algorithms for classification, clustering, regression...etc
# 5. [random]() is a Python module which is used to generate random numbers.

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import vgg16, resnet50
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, TensorBoard

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

print(tf.config.list_physical_devices("GPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # 2.  Cifar10 Dataset
#
# The CIFAR10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# Cifar10 dataset already exist on TensorFlow. Load these images using load_data() function from cifar10 module, which return train and test sets (x_train, y_train), (x_test, y_test).

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Using the "train_test_split" sklearn function in order to split the train dataset into train/validation subsets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, shuffle=True)

train_shape = x_train.shape
test_shape = x_test.shape
val_shape = x_val.shape

num_classes = np.max(y_test) + 1

print("Number of train images", train_shape[0])
print("Number of test images", test_shape[0])
print("Number of val images", val_shape[0])
print("Number of classes", num_classes)
print("Image size", train_shape[1:])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Number of train images 40000
# Number of test images 10000
# Number of val images 10000
# Number of classes 10
# Image size (32, 32, 3)

# %% [markdown]
# #  Data visualization
#
# Dispaly one image per class from the training or the testing datasets
#
# Using the given classes name, display the corresponding class name for each image.

# %%
classes_name = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

X = []
Y = []

for i, y in enumerate(y_test):
    if y in Y:
        continue
    
    Y.append(y)
    X.append(x_test[i])


fig = plt.figure(figsize = (12, 5))

for i in range(num_classes):
    ax = fig.add_subplot(2, 5, i + 1)
    img = X[i]
    lbl = classes_name[int(Y[i])]
    ax.set_xlabel("label: {}".format(lbl[0]), fontsize = 12)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(img, cmap = 'gray')

plt.show()

# %% [markdown]
# # Data Preprocessing
#
# Images are represented in 8-bits integer in range [0-255].
#
# You have to normalizing the pixel values range from [0-255] integer to [0-1] float

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0
x_val = x_val / 255.0

# %% [markdown]
# # 3. Train VGG16 on Cifar10 Benchmark from Scratch
#
# We instantiate the VGG16 [1] model from TensorFlow application, then we remove the top layer (classification layer) since it correspond to 1000 classes of ImageNet [2]
#
# Notice that we load only the feature extraction part of VGG16 architecture, the weights are randomly initialized. You will add the classification layer later
#
# vgg16.VGG16 function() will create the vgg16 model for you, we indicate that we want to remove the calssification layer by initializing include_top by False.
#
# You need to train your model from scratch. To do so, you need to initialize weights by None. Otherwise, you will get a pretrained model with imagenet weights.
#
# **References**
#
# [1] Simonyan, K., & Zisserman, A. (2014). Very deep convolutional networks for large-scale image recognition. arXiv preprint arXiv:1409.1556.
#
# [2] Deng, J. et al., 2009. Imagenet: A large-scale hierarchical image database. In 2009 IEEE conference on computer vision and pattern recognition. pp. 248–255.

# %%
vgg16_model = vgg16.VGG16(input_shape = (32, 32, 3), include_top = False, weights = None)

# %% [markdown]
# classification_layers() function takes as input your the base-model (feature extraction part), then connect it to the classification part.
#
# In this case we add only one layer on the top of VGG16 base-model, which is the output layer.
#
# You can customize your classifcation layers as you want (number of Dense layers, number of neurones per layer...)

# %%
def classification_layers(model):
  x = Flatten()(model.layers[-1].output)
  x = Dense(10, activation = 'softmax')(x)
  return x

# %% [markdown]
# In the following cell, you will be able to create your custom model.
#
# Using Model class from tf.keras.Model, which take as elements the "inputs" and the "outputs", then return the model instance.
#
# - model "input" is taken from the loaded vgg16_model.input
#
# - model "output" given by the classification_layers that we have already created.

# %%
output = classification_layers(vgg16_model)

# smodel refer to scatch model.
smodel = Model(inputs = vgg16_model.input, outputs = output)

# model.summary() will display a summary for your generated model.
smodel.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. Hyperparameters
#
# In this cell, we set the hyperparameters:
#
# - batch_size: Is the amount of data feed into the network once before performing one update
#
# - epochs: The number of training iteration
#
# - Learning_rate: Control how fast we make updates on the weights during the training process

# %%
batch_size = 128
epochs = 40
learning_rate = 0.1
lr_decay = 0.1

# %% [markdown]
# # Learning rate decay functions
#
# The following functions correspond to different learning rate scheduler:
#
# 1. step_decay : step-based learning rate decay. The initial learning rate is divided after performing several epochs.
# 2. exp_decay : exponential-based learning rate decay. The learning rate value will follow the expontial form starting from the initial value.

# %%
#Step decay
def step_decay(epoch):

    lr = learning_rate
    if epoch > 30:
        lr = lr * lr_decay**3
    elif epoch > 20:
        lr = lr * lr_decay**2   
    elif epoch > 10:
        lr = lr * lr_decay

    return lr

#Exponential decay
def exp_decay(epoch):
    
    lr = learning_rate * np.exp(-lr_decay * epoch)

    return lr

# %% [markdown]
# # Optimizer and loss function
#
# In the following cell, we:
# - define the loss function for our Model which is the Crossentropy function.
# - initialize the Gradient Descent Optimizer "SGD".
# - configure the model before training. We use for that "model.compile(...)"
# - metrics of evaluation for this model is the accuracy
# - callbakcs are functions called during training at certain points, to do some process (Saving the best checkpoint, Adjusting the learning rate...)
#     1. LearningRateScheduler : Used to adjust the learning rate during training.
#     2. ModelCheckpoint : Used for saving the best model according to the validation accuracy during training.

# %%
loss = "SparseCategoricalCrossentropy"

opt = SGD(learning_rate=learning_rate)

smodel.compile(optimizer=opt, loss = loss, metrics = ["accuracy"])

model_name_scratch = "vgg16_fromscratch"

lr_scheduler = LearningRateScheduler(step_decay, verbose=1)
checkpoint = ModelCheckpoint(filepath="./saved_models/{}.hdf5".format(model_name_scratch), save_best_only=True, monitor="val_accuracy", verbose=1)

#Group all your callbacks into a list for later use.
callbacks = [lr_scheduler, checkpoint]

# %% [markdown]
# # Model training
#
# Now that our model is ready, we can start learning using the function "model.fit".
#
# First, we have to shuffle our training data (shuffle = True).
#
# The list of callbacks predefined previously is given to the model.fit()
#
# => Analyze the parameters of the function "model.fit". The output of this funtion is deeply analyzed in the next cell.

# %%
sh = smodel.fit(x_train,y_train,shuffle=True,epochs=epochs,validation_data = (x_val,y_val), callbacks =callbacks  )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.7876 - accuracy: 0.3480
# Epoch 1: val_accuracy improved from 0.27120 to 0.38350, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.7877 - accuracy: 0.3479 - val_loss: 1.6704 - val_accuracy: 0.3835 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.6592 - accuracy: 0.3986
# Epoch 2: val_accuracy improved from 0.38350 to 0.41720, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.6592 - accuracy: 0.3986 - val_loss: 1.5830 - val_accuracy: 0.4172 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.5477 - accuracy: 0.4387
# Epoch 3: val_accuracy improved from 0.41720 to 0.45980, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 28ms/step - loss: 1.5478 - accuracy: 0.4386 - val_loss: 1.5123 - val_accuracy: 0.4598 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.4610 - accuracy: 0.4736
# Epoch 4: val_accuracy improved from 0.45980 to 0.46930, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.4610 - accuracy: 0.4736 - val_loss: 1.4724 - val_accuracy: 0.4693 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3760 - accuracy: 0.5061
# Epoch 5: val_accuracy improved from 0.46930 to 0.49120, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.3757 - accuracy: 0.5062 - val_loss: 1.4146 - val_accuracy: 0.4912 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2967 - accuracy: 0.5376
# Epoch 6: val_accuracy improved from 0.49120 to 0.54060, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.2966 - accuracy: 0.5376 - val_loss: 1.2788 - val_accuracy: 0.5406 - lr: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2158 - accuracy: 0.5658
# Epoch 7: val_accuracy improved from 0.54060 to 0.55800, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.2160 - accuracy: 0.5659 - val_loss: 1.2267 - val_accuracy: 0.5580 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1317 - accuracy: 0.5926
# Epoch 8: val_accuracy improved from 0.55800 to 0.57910, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.1317 - accuracy: 0.5926 - val_loss: 1.1838 - val_accuracy: 0.5791 - lr: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0477 - accuracy: 0.6263
# Epoch 9: val_accuracy did not improve from 0.57910
# 1250/1250 [==============================] - 36s 28ms/step - loss: 1.0480 - accuracy: 0.6262 - val_loss: 1.2544 - val_accuracy: 0.5604 - lr: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.01.
# Epoch 10/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9597 - accuracy: 0.6608
# Epoch 10: val_accuracy improved from 0.57910 to 0.59790, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.9597 - accuracy: 0.6608 - val_loss: 1.1494 - val_accuracy: 0.5979 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.01.
# Epoch 11/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8670 - accuracy: 0.6896
# Epoch 11: val_accuracy improved from 0.59790 to 0.60640, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.8670 - accuracy: 0.6896 - val_loss: 1.1449 - val_accuracy: 0.6064 - lr: 0.0100
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.001.
# Epoch 12/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.8149
# Epoch 12: val_accuracy improved from 0.60640 to 0.64250, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.5349 - accuracy: 0.8150 - val_loss: 1.1361 - val_accuracy: 0.6425 - lr: 0.0010
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.001.
# Epoch 13/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.4264 - accuracy: 0.8555
# Epoch 13: val_accuracy improved from 0.64250 to 0.64350, saving model to ./saved_models/vgg16_fromscratch.hdf5
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.4264 - accuracy: 0.8555 - val_loss: 1.1996 - val_accuracy: 0.6435 - lr: 0.0010
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.001.
# Epoch 14/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.3483 - accuracy: 0.8837
# Epoch 14: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 28ms/step - loss: 0.3483 - accuracy: 0.8837 - val_loss: 1.2867 - val_accuracy: 0.6402 - lr: 0.0010
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.001.
# Epoch 15/40
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.9114
# Epoch 15: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.2733 - accuracy: 0.9114 - val_loss: 1.4038 - val_accuracy: 0.6386 - lr: 0.0010
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.001.
# Epoch 16/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2035 - accuracy: 0.9371
# Epoch 16: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.2034 - accuracy: 0.9372 - val_loss: 1.5901 - val_accuracy: 0.6316 - lr: 0.0010
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.001.
# Epoch 17/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9598
# Epoch 17: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.1416 - accuracy: 0.9599 - val_loss: 1.7969 - val_accuracy: 0.6290 - lr: 0.0010
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.001.
# Epoch 18/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9784
# Epoch 18: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0885 - accuracy: 0.9784 - val_loss: 2.0511 - val_accuracy: 0.6283 - lr: 0.0010
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.001.
# Epoch 19/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9906
# Epoch 19: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 28ms/step - loss: 0.0507 - accuracy: 0.9906 - val_loss: 2.3114 - val_accuracy: 0.6271 - lr: 0.0010
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.001.
# Epoch 20/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9972
# Epoch 20: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0259 - accuracy: 0.9973 - val_loss: 2.5646 - val_accuracy: 0.6300 - lr: 0.0010
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.001.
# Epoch 21/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9992
# Epoch 21: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0131 - accuracy: 0.9992 - val_loss: 2.8035 - val_accuracy: 0.6290 - lr: 0.0010
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 22/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9997
# Epoch 22: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0069 - accuracy: 0.9998 - val_loss: 2.8379 - val_accuracy: 0.6288 - lr: 1.0000e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 23/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9998
# Epoch 23: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0062 - accuracy: 0.9998 - val_loss: 2.8659 - val_accuracy: 0.6297 - lr: 1.0000e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 24/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9999
# Epoch 24: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.0058 - accuracy: 0.9999 - val_loss: 2.8922 - val_accuracy: 0.6292 - lr: 1.0000e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 25/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9999
# Epoch 25: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0055 - accuracy: 0.9999 - val_loss: 2.9145 - val_accuracy: 0.6289 - lr: 1.0000e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 26/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9999
# Epoch 26: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0052 - accuracy: 0.9999 - val_loss: 2.9369 - val_accuracy: 0.6291 - lr: 1.0000e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 27/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.9578 - val_accuracy: 0.6293 - lr: 1.0000e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 28/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.9776 - val_accuracy: 0.6289 - lr: 1.0000e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 29/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.9959 - val_accuracy: 0.6287 - lr: 1.0000e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 30/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.0129 - val_accuracy: 0.6291 - lr: 1.0000e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 31/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 3.0312 - val_accuracy: 0.6294 - lr: 1.0000e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 32/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.0329 - val_accuracy: 0.6295 - lr: 1.0000e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 33/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.0346 - val_accuracy: 0.6294 - lr: 1.0000e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 34/40
# 1250/1250 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0363 - val_accuracy: 0.6293 - lr: 1.0000e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 35/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0380 - val_accuracy: 0.6292 - lr: 1.0000e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 36/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0397 - val_accuracy: 0.6289 - lr: 1.0000e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 37/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0413 - val_accuracy: 0.6290 - lr: 1.0000e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 38/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0430 - val_accuracy: 0.6291 - lr: 1.0000e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 39/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0447 - val_accuracy: 0.6290 - lr: 1.0000e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 40/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.64350
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.0463 - val_accuracy: 0.6290 - lr: 1.0000e-05

# %% [markdown]
# # 5. VGG16 model performance on Cifar10 (Training from Scratch)
#
# Let's analyze the logs of training.
#
# Here, we plot train and validation accuracy during traning.
#
# We also plot the loss w.r.t. epochs.
#
# - Comment the results

# %%
plt.figure(figsize=(12, 5))
plt.plot(sh.history["accuracy"], label = "train_acc")
plt.plot(sh.history["val_accuracy"], label = "val_acc")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Accuracy", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.figure(figsize=(12, 5))
plt.plot(sh.history["loss"], label = "train_loss")
plt.plot(sh.history["val_loss"], label = "val_loss")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Loss", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.show()

# %% [markdown]
# # Evaluation on the test set
#
# The funtion "model.evaluate" can be used to evaluate the performance of the model on the testset.
#
#
# First of all you need to load the best checkpoint saved by ModelCheckpoint callback. Otherwise, you would evaluate the last train step model.

# %%
smodel = load_model("/content/saved_models/vgg16_fromscratch.hdf5")
smodel.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 1.2495 - accuracy: 0.7768
# [1.2494984865188599, 0.7767999768257141]

# %% [markdown]
# # II. Transfer learning of VGG16 pretrained model on Cifar10 Benchmark
#
#
# After you have make a training from scratch of VGG16 on Cifar-10, from this section you will apply the transfer learning technique on the same application.
#
# You need only to set "weights" to "imagenet" inorder to load the pretrained VGG16 weights trained on ImageNet dataset.
#
# Imagenet dataset consists of 1.78 million different shape colour images in 1000 classes, with ~1000 images per class. There are 1.28 million training images and 50000 test images

# %%
vgg16_model = vgg16.VGG16(input_shape = (32, 32, 3), include_top = False, weights = "imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# In the following cell, you will be able to create your custom model.
#
# - Regarding model building using tf.keras.Model, nothing is changed for model compared to the training from scratch part.

# %%
output = classification_layers(vgg16_model)

TLmodel = Model(inputs = vgg16_model.input, outputs = output)

TLmodel.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 1. Freezing the base-model
#
# Inorder to perform transfer learning, we should keep the feature extraction part frozen.
#
# As default, all the layers are trainable. You should iterate through all the layers inorder to freeze the base-model using layer.trainable = False.

# %%
#Freezing the Conv layers
for layer in TLmodel.layers:
  if isinstance(layer, Dense):
    break
  layer.trainable = False

# %% [markdown]
# # 2. Optimizer and loss function
#
# We keep the same configuration as in training from scratch for a fair comparaison.

# %%
loss = "SparseCategoricalCrossentropy"

opt = SGD(learning_rate=learning_rate)

TLmodel.compile(optimizer=opt, loss = loss, metrics = ["accuracy"])

TL_model_name = "vgg16_transferlearning"

lr_scheduler = LearningRateScheduler(step_decay, verbose=1)
checkpoint = ModelCheckpoint(filepath="./saved_models/{}.hdf5".format(TL_model_name), save_best_only=True, monitor="val_accuracy", verbose=1)
callbacks = [lr_scheduler, checkpoint]

# %% [markdown]
# Fit your model as before using "fit" function.

# %%
th = TLmodel.fit(x_train,y_train,shuffle=True,epochs=epochs,validation_data = (x_val,y_val), callbacks =callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.1.
# Epoch 1/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.6290 - accuracy: 0.4283
# Epoch 1: val_accuracy improved from -inf to 0.45720, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.6289 - accuracy: 0.4285 - val_loss: 1.5305 - val_accuracy: 0.4572 - lr: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.1.
# Epoch 2/40
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.4213 - accuracy: 0.5062
# Epoch 2: val_accuracy improved from 0.45720 to 0.51870, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.4212 - accuracy: 0.5061 - val_loss: 1.3707 - val_accuracy: 0.5187 - lr: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.1.
# Epoch 3/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3643 - accuracy: 0.5265
# Epoch 3: val_accuracy did not improve from 0.51870
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.3644 - accuracy: 0.5265 - val_loss: 1.3944 - val_accuracy: 0.5166 - lr: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.1.
# Epoch 4/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.3358 - accuracy: 0.5390
# Epoch 4: val_accuracy did not improve from 0.51870
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.3359 - accuracy: 0.5390 - val_loss: 1.4516 - val_accuracy: 0.4889 - lr: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.1.
# Epoch 5/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.3169 - accuracy: 0.5424
# Epoch 5: val_accuracy improved from 0.51870 to 0.53440, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.3172 - accuracy: 0.5423 - val_loss: 1.3168 - val_accuracy: 0.5344 - lr: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.1.
# Epoch 6/40
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.3012 - accuracy: 0.5511
# Epoch 6: val_accuracy improved from 0.53440 to 0.53880, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.3008 - accuracy: 0.5512 - val_loss: 1.3423 - val_accuracy: 0.5388 - lr: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.1.
# Epoch 7/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2864 - accuracy: 0.5531
# Epoch 7: val_accuracy improved from 0.53880 to 0.53950, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.2864 - accuracy: 0.5530 - val_loss: 1.3370 - val_accuracy: 0.5395 - lr: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.1.
# Epoch 8/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2821 - accuracy: 0.5564
# Epoch 8: val_accuracy improved from 0.53950 to 0.57200, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.2819 - accuracy: 0.5564 - val_loss: 1.2321 - val_accuracy: 0.5720 - lr: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.1.
# Epoch 9/40
# 1250/1250 [==============================] - ETA: 0s - loss: 1.2705 - accuracy: 0.5609
# Epoch 9: val_accuracy did not improve from 0.57200
# 1250/1250 [==============================] - 14s 12ms/step - loss: 1.2705 - accuracy: 0.5609 - val_loss: 1.3201 - val_accuracy: 0.5395 - lr: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.1.
# Epoch 10/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.2636 - accuracy: 0.5631
# Epoch 10: val_accuracy improved from 0.57200 to 0.57290, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.2626 - accuracy: 0.5634 - val_loss: 1.2312 - val_accuracy: 0.5729 - lr: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.1.
# Epoch 11/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2570 - accuracy: 0.5653
# Epoch 11: val_accuracy did not improve from 0.57290
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.2565 - accuracy: 0.5654 - val_loss: 1.2433 - val_accuracy: 0.5682 - lr: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 12/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1428 - accuracy: 0.6078
# Epoch 12: val_accuracy improved from 0.57290 to 0.59040, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1429 - accuracy: 0.6078 - val_loss: 1.1841 - val_accuracy: 0.5904 - lr: 0.0100
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 13/40
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1390 - accuracy: 0.6069
# Epoch 13: val_accuracy did not improve from 0.59040
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1387 - accuracy: 0.6069 - val_loss: 1.1848 - val_accuracy: 0.5892 - lr: 0.0100
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 14/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1378 - accuracy: 0.6087
# Epoch 14: val_accuracy did not improve from 0.59040
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1377 - accuracy: 0.6088 - val_loss: 1.1868 - val_accuracy: 0.5866 - lr: 0.0100
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 15/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1381 - accuracy: 0.6082
# Epoch 15: val_accuracy did not improve from 0.59040
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1378 - accuracy: 0.6084 - val_loss: 1.1856 - val_accuracy: 0.5882 - lr: 0.0100
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 16/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1371 - accuracy: 0.6101
# Epoch 16: val_accuracy improved from 0.59040 to 0.59050, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1365 - accuracy: 0.6102 - val_loss: 1.1827 - val_accuracy: 0.5905 - lr: 0.0100
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 17/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1368 - accuracy: 0.6078
# Epoch 17: val_accuracy improved from 0.59050 to 0.59180, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1367 - accuracy: 0.6078 - val_loss: 1.1781 - val_accuracy: 0.5918 - lr: 0.0100
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 18/40
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1360 - accuracy: 0.6101
# Epoch 18: val_accuracy did not improve from 0.59180
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1360 - accuracy: 0.6101 - val_loss: 1.1800 - val_accuracy: 0.5881 - lr: 0.0100
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 19/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1358 - accuracy: 0.6106
# Epoch 19: val_accuracy did not improve from 0.59180
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1356 - accuracy: 0.6107 - val_loss: 1.1856 - val_accuracy: 0.5874 - lr: 0.0100
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 20/40
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1352 - accuracy: 0.6093
# Epoch 20: val_accuracy did not improve from 0.59180
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1350 - accuracy: 0.6093 - val_loss: 1.1807 - val_accuracy: 0.5903 - lr: 0.0100
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 21/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1349 - accuracy: 0.6102
# Epoch 21: val_accuracy did not improve from 0.59180
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1350 - accuracy: 0.6101 - val_loss: 1.1847 - val_accuracy: 0.5888 - lr: 0.0100
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 22/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1282 - accuracy: 0.6131
# Epoch 22: val_accuracy improved from 0.59180 to 0.59330, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1282 - accuracy: 0.6130 - val_loss: 1.1767 - val_accuracy: 0.5933 - lr: 0.0010
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 23/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1277 - accuracy: 0.6133
# Epoch 23: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1277 - accuracy: 0.6133 - val_loss: 1.1758 - val_accuracy: 0.5919 - lr: 0.0010
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 24/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1278 - accuracy: 0.6135
# Epoch 24: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1277 - accuracy: 0.6135 - val_loss: 1.1769 - val_accuracy: 0.5920 - lr: 0.0010
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 25/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1276 - accuracy: 0.6133
# Epoch 25: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1276 - accuracy: 0.6132 - val_loss: 1.1767 - val_accuracy: 0.5912 - lr: 0.0010
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 26/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1280 - accuracy: 0.6135
# Epoch 26: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1276 - accuracy: 0.6135 - val_loss: 1.1769 - val_accuracy: 0.5933 - lr: 0.0010
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 27/40
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1274 - accuracy: 0.6128
# Epoch 27: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1276 - accuracy: 0.6127 - val_loss: 1.1759 - val_accuracy: 0.5928 - lr: 0.0010
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 28/40
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1272 - accuracy: 0.6135
# Epoch 28: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1275 - accuracy: 0.6134 - val_loss: 1.1758 - val_accuracy: 0.5918 - lr: 0.0010
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 29/40
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1275 - accuracy: 0.6133
# Epoch 29: val_accuracy did not improve from 0.59330
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1275 - accuracy: 0.6133 - val_loss: 1.1756 - val_accuracy: 0.5923 - lr: 0.0010
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 30/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1276 - accuracy: 0.6135
# Epoch 30: val_accuracy improved from 0.59330 to 0.59400, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.1275 - accuracy: 0.6136 - val_loss: 1.1757 - val_accuracy: 0.5940 - lr: 0.0010
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0010000000000000002.
# Epoch 31/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1275 - accuracy: 0.6133
# Epoch 31: val_accuracy improved from 0.59400 to 0.59440, saving model to ./saved_models/vgg16_transferlearning.hdf5
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1274 - accuracy: 0.6134 - val_loss: 1.1754 - val_accuracy: 0.5944 - lr: 0.0010
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 32/40
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1265 - accuracy: 0.6136
# Epoch 32: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1267 - accuracy: 0.6136 - val_loss: 1.1756 - val_accuracy: 0.5928 - lr: 1.0000e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 33/40
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1264 - accuracy: 0.6139
# Epoch 33: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6139 - val_loss: 1.1756 - val_accuracy: 0.5928 - lr: 1.0000e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 34/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1267 - accuracy: 0.6137
# Epoch 34: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6138 - val_loss: 1.1757 - val_accuracy: 0.5934 - lr: 1.0000e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 35/40
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.6137
# Epoch 35: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6137 - val_loss: 1.1758 - val_accuracy: 0.5931 - lr: 1.0000e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 36/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1264 - accuracy: 0.6138
# Epoch 36: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6138 - val_loss: 1.1756 - val_accuracy: 0.5931 - lr: 1.0000e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 37/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1266 - accuracy: 0.6138
# Epoch 37: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6138 - val_loss: 1.1757 - val_accuracy: 0.5931 - lr: 1.0000e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 38/40
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1265 - accuracy: 0.6139
# Epoch 38: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6137 - val_loss: 1.1757 - val_accuracy: 0.5932 - lr: 1.0000e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 39/40
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1265 - accuracy: 0.6139
# Epoch 39: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6139 - val_loss: 1.1757 - val_accuracy: 0.5934 - lr: 1.0000e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00010000000000000003.
# Epoch 40/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1267 - accuracy: 0.6138
# Epoch 40: val_accuracy did not improve from 0.59440
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.1266 - accuracy: 0.6139 - val_loss: 1.1757 - val_accuracy: 0.5933 - lr: 1.0000e-04

# %% [markdown]
# # Evaluation on the test set
#
# Evaluate the obtained model with "evaluate" function using the test set used before.
#
# First of all you need to load the best checkpoint saved by ModelCheckpoint callback. Otherwise, you would evaluate the last train step model.

# %%
TLmodel = load_model("/content/saved_models/vgg16_transferlearning.hdf5")
TLmodel.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 1.1939 - accuracy: 0.5852
# [1.1939228773117065, 0.5852000117301941]

# %% [markdown]
# # 3. Display the Training & Validation plots
#
# Let's analyze the logs of training.
#
# Here, we plot train and validation accuracy during traning.
#
# We also plot the loss w.r.t. epochs.
#
# - Comment the results

# %%
plt.figure(figsize=(12, 5))
plt.plot(th.history["accuracy"], label = "train_acc")
plt.plot(th.history["val_accuracy"], label = "val_acc")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Accuracy", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.figure(figsize=(12, 5))
plt.plot(th.history["loss"], label = "train_loss")
plt.plot(th.history["val_loss"], label = "val_loss")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Loss", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.show()

# %% [markdown]
# # III. Fine tuning
#
# As you know, fine tuning is an important step that could improve the model performence rightafter applying the transfer learning.
#
# To do so, you should load the best checkpoint your model (obtained with transfer learning) as a starting point for the fine tuning process.

# %%
FTmodel = load_model("/content/saved_models/vgg16_transferlearning.hdf5")

# %% [markdown]
# # 1. How much layer should we freeze?
#
# In this cell you will be able to take the control on how much layer you should freeze using the slide bar
#
# 1. You should execute this cell once to be able to see the slide barr.
# 2. For the first step, make all the layers trainable (trainable convX : True), then execute all the reamining cells untill the end.
# 3. Make sure that you have saved your model and plots for the previous test.
# 4. Reload again the model from the previous cell to remake a new test
# 5. For the second test, do not freeze all the layers, make some of them unfreeze. You should keep the same configuration of hyperparameters for a fair comparaison.
# 6. Feel free to do several experiments.

# %%
# import ipywidgets.interact class, this class will represent a slide bar.
from ipywidgets import interact

conv_layers = [layer for layer in FTmodel.layers if isinstance(layer, tf.keras.layers.Conv2D)]

number_of_convs = len(conv_layers)
# use interact decorator to decorate the function, so the function can receive the slide bar's value with parameter x.
print(number_of_convs)
@interact(x=(0, number_of_convs))
def double_number(x):

    #Freezing the Conv layers
    for layer in FTmodel.layers:
        if isinstance(layer, Dense):
            break
        layer.trainable = False

    i = 0
    for layer in FTmodel.layers:
        if isinstance(layer, tf.keras.layers.Conv2D):
            if i < x:
                layer.trainable = True
                i+=1
            else:
                break
            
    
    i = 1
    for layer in FTmodel.layers:
        if isinstance(layer, tf.keras.layers.Conv2D):
            print("Train conv{} : {}".format(i, layer.trainable))
            i+=1
# Out:
# 13
# interactive(children=(IntSlider(value=6, description='x', max=13), Output()), _dom_classes=('widget-interact',…

# %% [markdown]
# # 2. Optimizer and loss function
#
# The only change on the following cell is the learning rate value. You should start with smaller learning rate.
#
# Divide the initial learning rate by 10 for example.

# %%
loss = "SparseCategoricalCrossentropy"

learning_rate = 0.1
learning_rate = learning_rate / 10

opt = SGD(learning_rate=learning_rate)

FTmodel.compile(optimizer=opt, loss = loss, metrics = ["accuracy"])

FT_model_name = "vgg16_finetuning"

lr_scheduler = LearningRateScheduler(step_decay, verbose=1)
checkpoint = ModelCheckpoint(filepath="./saved_models/{}.hdf5".format(FT_model_name), save_best_only=True, monitor="val_accuracy", verbose=1)
callbacks = [lr_scheduler, checkpoint]

# %% [markdown]
# Start fine tuning !

# %%
fh = FTmodel.fit(x_train,y_train,shuffle=True,epochs=epochs,validation_data = (x_val,y_val), callbacks =callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2232 - accuracy: 0.5692
# Epoch 1: val_accuracy improved from -inf to 0.66690, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 28s 22ms/step - loss: 1.2230 - accuracy: 0.5693 - val_loss: 0.9637 - val_accuracy: 0.6669 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8560 - accuracy: 0.7012
# Epoch 2: val_accuracy improved from 0.66690 to 0.71540, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.8557 - accuracy: 0.7013 - val_loss: 0.8200 - val_accuracy: 0.7154 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7527 - accuracy: 0.7400
# Epoch 3: val_accuracy improved from 0.71540 to 0.74330, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.7526 - accuracy: 0.7400 - val_loss: 0.7583 - val_accuracy: 0.7433 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6854 - accuracy: 0.7626
# Epoch 4: val_accuracy improved from 0.74330 to 0.75270, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.6853 - accuracy: 0.7626 - val_loss: 0.7249 - val_accuracy: 0.7527 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6270 - accuracy: 0.7810
# Epoch 5: val_accuracy improved from 0.75270 to 0.77430, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.6268 - accuracy: 0.7810 - val_loss: 0.6685 - val_accuracy: 0.7743 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5822 - accuracy: 0.7977
# Epoch 6: val_accuracy did not improve from 0.77430
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.5821 - accuracy: 0.7977 - val_loss: 0.6720 - val_accuracy: 0.7716 - lr: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.8131
# Epoch 7: val_accuracy improved from 0.77430 to 0.79510, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.5383 - accuracy: 0.8130 - val_loss: 0.6138 - val_accuracy: 0.7951 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5012 - accuracy: 0.8282
# Epoch 8: val_accuracy did not improve from 0.79510
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.5012 - accuracy: 0.8283 - val_loss: 0.6363 - val_accuracy: 0.7827 - lr: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.4640 - accuracy: 0.8402
# Epoch 9: val_accuracy improved from 0.79510 to 0.80810, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.4639 - accuracy: 0.8403 - val_loss: 0.5771 - val_accuracy: 0.8081 - lr: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.01.
# Epoch 10/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.4339 - accuracy: 0.8496
# Epoch 10: val_accuracy improved from 0.80810 to 0.81060, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.4338 - accuracy: 0.8496 - val_loss: 0.5656 - val_accuracy: 0.8106 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.01.
# Epoch 11/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.4014 - accuracy: 0.8615
# Epoch 11: val_accuracy did not improve from 0.81060
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.4014 - accuracy: 0.8615 - val_loss: 0.5751 - val_accuracy: 0.8098 - lr: 0.0100
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.001.
# Epoch 12/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.3082 - accuracy: 0.9001
# Epoch 12: val_accuracy improved from 0.81060 to 0.82860, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.3081 - accuracy: 0.9002 - val_loss: 0.5257 - val_accuracy: 0.8286 - lr: 0.0010
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.001.
# Epoch 13/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2946 - accuracy: 0.9035
# Epoch 13: val_accuracy did not improve from 0.82860
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2946 - accuracy: 0.9036 - val_loss: 0.5261 - val_accuracy: 0.8276 - lr: 0.0010
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.001.
# Epoch 14/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2881 - accuracy: 0.9060
# Epoch 14: val_accuracy improved from 0.82860 to 0.83040, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2881 - accuracy: 0.9061 - val_loss: 0.5247 - val_accuracy: 0.8304 - lr: 0.0010
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.001.
# Epoch 15/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2824 - accuracy: 0.9084
# Epoch 15: val_accuracy did not improve from 0.83040
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2824 - accuracy: 0.9084 - val_loss: 0.5288 - val_accuracy: 0.8287 - lr: 0.0010
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.001.
# Epoch 16/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2771 - accuracy: 0.9099
# Epoch 16: val_accuracy did not improve from 0.83040
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2771 - accuracy: 0.9099 - val_loss: 0.5296 - val_accuracy: 0.8281 - lr: 0.0010
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.001.
# Epoch 17/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2725 - accuracy: 0.9114
# Epoch 17: val_accuracy did not improve from 0.83040
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2726 - accuracy: 0.9114 - val_loss: 0.5266 - val_accuracy: 0.8297 - lr: 0.0010
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.001.
# Epoch 18/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2679 - accuracy: 0.9137
# Epoch 18: val_accuracy improved from 0.83040 to 0.83070, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2679 - accuracy: 0.9137 - val_loss: 0.5289 - val_accuracy: 0.8307 - lr: 0.0010
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.001.
# Epoch 19/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2633 - accuracy: 0.9142
# Epoch 19: val_accuracy improved from 0.83070 to 0.83120, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2633 - accuracy: 0.9142 - val_loss: 0.5276 - val_accuracy: 0.8312 - lr: 0.0010
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.001.
# Epoch 20/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2589 - accuracy: 0.9163
# Epoch 20: val_accuracy did not improve from 0.83120
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2590 - accuracy: 0.9163 - val_loss: 0.5262 - val_accuracy: 0.8308 - lr: 0.0010
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.001.
# Epoch 21/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2549 - accuracy: 0.9177
# Epoch 21: val_accuracy did not improve from 0.83120
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2549 - accuracy: 0.9177 - val_loss: 0.5298 - val_accuracy: 0.8286 - lr: 0.0010
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 22/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2442 - accuracy: 0.9229
# Epoch 22: val_accuracy improved from 0.83120 to 0.83200, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2442 - accuracy: 0.9230 - val_loss: 0.5251 - val_accuracy: 0.8320 - lr: 1.0000e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 23/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2431 - accuracy: 0.9230
# Epoch 23: val_accuracy did not improve from 0.83200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2431 - accuracy: 0.9230 - val_loss: 0.5256 - val_accuracy: 0.8318 - lr: 1.0000e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 24/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2426 - accuracy: 0.9232
# Epoch 24: val_accuracy did not improve from 0.83200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2425 - accuracy: 0.9232 - val_loss: 0.5265 - val_accuracy: 0.8318 - lr: 1.0000e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 25/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2420 - accuracy: 0.9236
# Epoch 25: val_accuracy improved from 0.83200 to 0.83210, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2420 - accuracy: 0.9236 - val_loss: 0.5259 - val_accuracy: 0.8321 - lr: 1.0000e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 26/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2415 - accuracy: 0.9234
# Epoch 26: val_accuracy improved from 0.83210 to 0.83280, saving model to ./saved_models/vgg16_finetuning.hdf5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2415 - accuracy: 0.9234 - val_loss: 0.5264 - val_accuracy: 0.8328 - lr: 1.0000e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 27/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2410 - accuracy: 0.9240
# Epoch 27: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2410 - accuracy: 0.9240 - val_loss: 0.5268 - val_accuracy: 0.8324 - lr: 1.0000e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 28/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.9240
# Epoch 28: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2406 - accuracy: 0.9241 - val_loss: 0.5270 - val_accuracy: 0.8320 - lr: 1.0000e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 29/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2402 - accuracy: 0.9243
# Epoch 29: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2401 - accuracy: 0.9243 - val_loss: 0.5268 - val_accuracy: 0.8314 - lr: 1.0000e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 30/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2397 - accuracy: 0.9247
# Epoch 30: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2396 - accuracy: 0.9247 - val_loss: 0.5268 - val_accuracy: 0.8322 - lr: 1.0000e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00010000000000000002.
# Epoch 31/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2393 - accuracy: 0.9247
# Epoch 31: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2393 - accuracy: 0.9247 - val_loss: 0.5276 - val_accuracy: 0.8319 - lr: 1.0000e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 32/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2380 - accuracy: 0.9251
# Epoch 32: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2380 - accuracy: 0.9251 - val_loss: 0.5273 - val_accuracy: 0.8321 - lr: 1.0000e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 33/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2378 - accuracy: 0.9252
# Epoch 33: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2379 - accuracy: 0.9251 - val_loss: 0.5272 - val_accuracy: 0.8323 - lr: 1.0000e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 34/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9253
# Epoch 34: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2378 - accuracy: 0.9253 - val_loss: 0.5272 - val_accuracy: 0.8324 - lr: 1.0000e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 35/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9252
# Epoch 35: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2378 - accuracy: 0.9252 - val_loss: 0.5271 - val_accuracy: 0.8320 - lr: 1.0000e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 36/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2378 - accuracy: 0.9253
# Epoch 36: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2378 - accuracy: 0.9254 - val_loss: 0.5272 - val_accuracy: 0.8321 - lr: 1.0000e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 37/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9255
# Epoch 37: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2377 - accuracy: 0.9255 - val_loss: 0.5272 - val_accuracy: 0.8320 - lr: 1.0000e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 38/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9253
# Epoch 38: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 28s 22ms/step - loss: 0.2377 - accuracy: 0.9254 - val_loss: 0.5272 - val_accuracy: 0.8321 - lr: 1.0000e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 39/40
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9253
# Epoch 39: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2376 - accuracy: 0.9254 - val_loss: 0.5272 - val_accuracy: 0.8323 - lr: 1.0000e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 40/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2376 - accuracy: 0.9253
# Epoch 40: val_accuracy did not improve from 0.83280
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.2376 - accuracy: 0.9254 - val_loss: 0.5272 - val_accuracy: 0.8320 - lr: 1.0000e-05

# %% [markdown]
# # Evaluation on the test set
#
# Load the best checkpoint that achieved the higher val_accuracy during fine tuning using load_model function.
#
# Evaluate the loaded model.

# %%
FTmodel = load_model("/content/saved_models/vgg16_finetuning.hdf5")
FTmodel.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5544 - accuracy: 0.8170
# [0.5543501973152161, 0.8169999718666077]

# %% [markdown]
# # 3. Display the Training & Validation plots
#
# Let's analyze the logs of fine tuning.
#
# Here, we plot train/validation accuracy/loss respectively during the fine tuning.
#
# Comment the obtained result for each test in case :
# - Fine tune the whole model
# - Fine tune a part of the feature extraction model
# - Comment and explain the results in all the cases

# %%
plt.figure(figsize=(12, 5))
plt.plot(fh.history["accuracy"], label = "train_acc")
plt.plot(fh.history["val_accuracy"], label = "val_acc")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Accuracy", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.figure(figsize=(12, 5))
plt.plot(fh.history["loss"], label = "train_loss")
plt.plot(fh.history["val_loss"], label = "val_loss")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Loss", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.show()
